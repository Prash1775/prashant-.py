# %% [markdown]
# <a href="https://colab.research.google.com/github/Prash1775/prashant-.py/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("SAP-4000.csv")

# %%
# 1. Clean column names
df.columns = df.columns.str.strip()

# 2. Basic Descriptive Analysis
print("\nBasic Info:\n", df.info())
print("\nSummary Stats:\n", df.describe())
print("\nValue Counts:\n", df['Region'].value_counts())
print("\nParent Education Levels:\n", df['Parent Education'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             4000 non-null   object
#  1   HoursStudied/Week  4000 non-null   float64
#  2   Tutoring           4000 non-null   object
#  3   Region             4000 non-null   object
#  4   Attendance(%)      4000 non-null   float64
#  5   Parent Education   3578 non-null   object
#  6   Exam_Score         4000 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 218.9+ KB
#
# Basic Info:
#  None
#
# Summary Stats:
#         HoursStudied/Week  Attendance(%)   Exam_Score
# count        4000.000000    4000.000000  4000.000000
# mean            9.861025      75.224150    71.107775
# std             3.713801      14.496906    16.748950
# min             0.000000      50.000000    16.600000
# 25%             7.400000      62.600000    59.300000
# ...

# %%
# 3. Pie Chart – Gender Distribution
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Gender Distribution")
plt.tight_layout()
plt.show()

# %%
# Gender-based performance
gender_avg = df.groupby('Gender')['Exam_Score'].mean()
print("Average Exam Score by Gender:")
print(gender_avg)
# Out:
# Average Exam Score by Gender:
# Gender
# Female    71.944951
# Male      70.236429
# Name: Exam_Score, dtype: float64

# %%
# 4. Bar Chart – Average Exam Score by Region
avg_score_region = df.groupby('Region')['Exam_Score'].mean()
plt.figure(figsize=(6, 5))
avg_score_region.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Average Exam Score by Region")
plt.ylabel("Average Score")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Region-based performance
region_avg = df.groupby('Region')['Exam_Score'].mean()
print("\nAverage Exam Score by Region:")
print(region_avg)
# Out:
# Average Exam Score by Region:
# Region
# Rural    69.231452
# Urban    72.328972
# Name: Exam_Score, dtype: float64

# %%
# 5. Line Chart – Average Exam Score by Study Hours (grouped)
df['Study_Hour_Group'] = pd.cut(df['HoursStudied/Week'], bins=[0, 5, 10, 15, 20, 25], labels=['0-5', '6-10', '11-15', '16-20', '21-25'])
avg_score_by_hours = df.groupby('Study_Hour_Group')['Exam_Score'].mean()
plt.figure(figsize=(7, 5))
avg_score_by_hours.plot(kind='line', marker='o', color='green')
plt.title("Exam Score by Study Hours Group")
plt.xlabel("Study Hours per Week")
plt.ylabel("Average Exam Score")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-3918770515>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_score_by_hours = df.groupby('Study_Hour_Group')['Exam_Score'].mean()

# %%
# 6. Line Graph – Attendance vs Exam Score (trend)
attendance_score = df.sort_values('Attendance(%)')[['Attendance(%)', 'Exam_Score']]
plt.figure(figsize=(8, 5))
plt.plot(attendance_score['Attendance(%)'], attendance_score['Exam_Score'], linestyle='-', marker='', alpha=0.3)
plt.title("Exam Score Trend Based on Attendance")
plt.xlabel("Attendance (%)")
plt.ylabel("Exam Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correlation insights
print("\nCorrelation Matrix:")
print(df[['HoursStudied/Week', 'Attendance(%)', 'Exam_Score']].corr())
# Out:
# Correlation Matrix:
#                    HoursStudied/Week  Attendance(%)  Exam_Score
# HoursStudied/Week           1.000000       0.003607    0.819812
# Attendance(%)               0.003607       1.000000    0.238570
# Exam_Score                  0.819812       0.238570    1.000000

# %%
# Parent Education impact
parent_edu_avg = df.groupby('Parent Education')['Exam_Score'].mean()
print("\nAverage Exam Score by Parent Education:")
print(parent_edu_avg)


# Tutoring vs No Tutoring
tutoring_avg = df.groupby('Tutoring')['Exam_Score'].mean()
print("\nAverage Exam Score with/without Tutoring:")
print(tutoring_avg)

# Study hour group comparison
print("\nAverage Score by Study Hour Groups:")
print(avg_score_by_hours)
# Out:
# Average Exam Score by Parent Education:
# Parent Education
# Primary      69.517097
# Secondary    71.140063
# Tertiary     73.190979
# Name: Exam_Score, dtype: float64
#
# Average Exam Score with/without Tutoring:
# Tutoring
# No     66.682761
# Yes    81.038037
# Name: Exam_Score, dtype: float64
#
# Average Score by Study Hour Groups:
# Study_Hour_Group
# 0-5      47.340500
# 6-10     63.741472
# 11-15    80.308323
# 16-20    92.401786
# 21-25          NaN
# Name: Exam_Score, dtype: float64
